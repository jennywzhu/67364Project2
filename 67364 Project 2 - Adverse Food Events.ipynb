# %% [markdown]
# # Project 2 - Analyzing Adverse Food Events

# %% [markdown]
# Dylan Schwartz, Jenny Zhu

# %% [markdown]
# ## Project Overview
# Our project will aim to predict the potential symptoms a person may experience after consuming a particular food, given the food type and the person’s age and gender. We are interested in determining if certain food brands or food types can lead to adverse health effects in college students, as well as other age and gender groups. We propose developing a machine learning model to classify records into groups of potential health symptoms based on certain features, such as a person’s age, gender, the food’s brand name, and the food category.

# %% [markdown]
# ## Questions:
#
# 1. What symptoms are most prevalent?
# 2. Given a person’s age, gender, reaction date, and food brand, what is the most likely health outcome, and what are the most likely symptoms to be experienced?
# 3. Can we predict the food a person consumed based on their symptoms?
# 4. What kind of foods should certain demographics avoid eating?

# %% [markdown]
# ## Terminology:

# %% [markdown]
# ### * Cleaning the data *

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import datetime
import collections
from IPython.display import Image

# %matplotlib inline

# %%
# Importing Adverse Food Events Table
app_cols = ['RA_Report #', 'RA_CAERS Created Date', 'AEC_Event Start Date', 'PRI_Product Role', 'PRI_Reported Brand/Product Name', 'PRI_FDA Industry Code', 'PRI_FDA Industry Name', 'CI_Age at Adverse Event', 'CI_Age Unit', 'CI_Gender', 'AEC_One Row Outcomes', 'SYM_One Row Coded Symptoms']
pre_events = pd.read_csv('adversefoodevents.csv', dtype=object , names=app_cols,
                     encoding='latin-1')
# deleting columns that are not needed
pre_events  = pre_events.drop(0)
pre_events = pre_events.drop('RA_Report #', axis=1)
pre_events = pre_events.drop('RA_CAERS Created Date', axis=1)

pre_events.head()
# Out:
#   AEC_Event Start Date PRI_Product Role  \
# 1             8/4/2003          Suspect
# 2             8/4/2003          Suspect
# 3                  NaN          Suspect
# 4           11/24/2003          Suspect
# 5                  NaN          Suspect
#
#                      PRI_Reported Brand/Product Name PRI_FDA Industry Code  \
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                     3
# 2      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                     3
# 3  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                    13
# 4                         ENFAMIL LIPIL BABY FORMULA                    40
# 5                         ENFIMIL LIPIL BABY FORMULA                    40
#
#          PRI_FDA Industry Name CI_Age at Adverse Event    CI_Age Unit  \
# 1  Bakery Prod/Dough/Mix/Icing                       2        Year(s)
# 2  Bakery Prod/Dough/Mix/Icing                       2        Year(s)
# 3               Ice Cream Prod                     NaN  Not Available
# 4               Baby Food Prod                       3       Month(s)
# 5               Baby Food Prod                     NaN  Not Available
#
#        CI_Gender                               AEC_One Row Outcomes  \
# 1         Female  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 2         Female  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 3         Female                                      VISITED AN ER
# 4  Not Available                      NON-SERIOUS INJURIES/ ILLNESS
# 5  Not Available                     VISITED A HEALTH CARE PROVIDER
#
#                           SYM_One Row Coded Symptoms
# 1  SWELLING FACE, RASH, WHEEZING, COUGH, HOSPITAL...
# 2  SWELLING FACE, WHEEZING, COUGH, RASH, HOSPITAL...
# 3                       NAUSEA, DYSGEUSIA, DIARRHOEA
# 4                GASTROINTESTINAL DISORDER, VOMITING
# 5    GASTROINTESTINAL DISORDER, PHYSICAL EXAMINATION

# %%
# # Creating events table (cleaned version of the pre_events table)

# ## HELPER FUNCTIONS #####

# # Helper function that assigns empty start date values to the current date
def clean_start_date(v):
    if pd.isnull(v):
        return datetime.datetime.now().strftime("%Y-%m-%d")
    else:
        date = v.split("/")
        c_date = datetime.date(int(date[2]), int(date[0]), int(date[1])).strftime("%Y-%m-%d")
        return c_date
    
def get_age(row):
    age = row['CI_Age at Adverse Event']
    if(pd.isnull(age) or isinstance(int(age), int) == False):
        return '-1' 
    elif(row['CI_Age Unit'] == 'Month(s)'):
        return str(int(age)/12)
    else:
        return age

# # Helper function that converts comma-separated symptoms into a list
def list_symptoms(x): 
    if(isinstance(x, str)):
        symptoms_list = x.split(",")
        return symptoms_list
    else:
        return []


# ##########################

# #creating cleaned food events dataframes 
events = pre_events.copy(deep=True)

# # Cleaning adverse reaction start date
events['AEC_Event Start Date'] = pre_events['AEC_Event Start Date'].apply( lambda v: clean_start_date(v))

# # Making a new column for the patient's age in years
events['year_age'] = pre_events.apply( lambda row: get_age(row), axis=1)
events = events.drop('CI_Age at Adverse Event', axis=1)
events = events.drop('CI_Age Unit', axis=1)

# # # Converting comma-separated symptoms into a list of symptoms 
events['SYM_One Row Coded Symptoms'] = pre_events['SYM_One Row Coded Symptoms'].apply( lambda x: list_symptoms(x))

events.head(50)
# Out:
#    AEC_Event Start Date PRI_Product Role  \
# 1            2003-08-04          Suspect
# 2            2003-08-04          Suspect
# 3            2018-04-24          Suspect
# 4            2003-11-24          Suspect
# 5            2018-04-24          Suspect
# 6            2003-12-21          Suspect
# 7            2018-04-24          Suspect
# 8            2003-12-01          Suspect
# 9            2003-12-01          Suspect
# 10           2018-04-24          Suspect
# 11           2003-10-27          Suspect
# 12           2003-10-27          Suspect
# 13           2003-10-27          Suspect
# 14           2003-11-05          Suspect
# 15           2018-04-24          Suspect
# 16           2003-12-30          Suspect
# 17           2003-11-22          Suspect
# 18           2001-09-05          Suspect
# 19           2003-03-04          Suspect
# 20           2018-04-24          Suspect
# 21           2003-11-15          Suspect
# 22           2018-04-24          Suspect
# 23           2003-11-01          Suspect
# 24           2003-11-01          Suspect
# 25           2003-11-01          Suspect
# 26           2003-11-01          Suspect
# 27           2003-11-01          Suspect
# 28           2003-11-01          Suspect
# 29           2003-11-01          Suspect
# 30           2003-11-01          Suspect
# 31           2003-11-01          Suspect
# 32           2003-11-01          Suspect
# 33           2003-08-21          Suspect
# 34           2003-08-21          Suspect
# 35           2003-08-21          Suspect
# 36           2003-05-24          Suspect
# 37           1996-01-01          Suspect
# 38           2018-04-24          Suspect
# 39           2018-04-24          Suspect
# 40           1998-11-06          Suspect
# 41           2018-04-24          Suspect
# 42           2018-04-24          Suspect
# 43           2018-04-24          Suspect
# 44           2018-04-24          Suspect
# 45           2003-12-05          Suspect
# 46           2002-07-01          Suspect
# 47           2003-12-31          Suspect
# 48           2003-12-31          Suspect
# 49           2003-12-31          Suspect
# 50           2003-11-01          Suspect
#
#                       PRI_Reported Brand/Product Name PRI_FDA Industry Code  \
# 1       MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                     3
# 2       MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                     3
# 3   KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                    13
# 4                          ENFAMIL LIPIL BABY FORMULA                    40
# 5                          ENFIMIL LIPIL BABY FORMULA                    40
# 6         FRITO LAY FUNYUNS ONION FLAVOR, ONION RINGS                     7
# 7                                               GRAPE                    20
# 8                                 HERBALIFE RELAX NOW                    54
# 9                             HERBALIFE TOTAL CONTROL                    54
# 10                                            YOHIMBE                    54
# 11         CAL-C PEACH TROPIC ENRICHED BEVERAGE BLEND                    29
# 12         CAL-C PEACH TROPIC ENRICHED BEVERAGE BLEND                    29
# 13         CAL-C PEACH TROPIC ENRICHED BEVERAGE BLEND                    29
# 14                 I CONTACT LIP-INK (SEMI-PERMANENT)                    53
# 15                            H.P. HOOD HALF AND HALF                     9
# 16   LACTAID REDUCED FAT (2%) MILK; 100% LACTOSE FREE                     9
# 17                                     METOBOLITE 356                    54
# 18                                         METABOLIFE                    54
# 19                              METABOLIFE METABOLIFE                    54
# 20                     ENIVA MINERALS FOR LIFE-SILVER                    54
# 21                                            AVLIMIL                    54
# 22                                            AVLIMIL                    54
# 23                                             COFFEE                    31
# 24                            DIET CAFFEINE FREE COKE                    29
# 25                                          DIET COKE                    29
# 26                                         DIET PEPSI                    29
# 27                                        DIET SPRITE                    29
# 28                                               JAMS                    22
# 29                                   LISTERINE STRIPS                    53
# 30                                         NUTRASWEET                    45
# 31                                           PUDDINGS                    35
# 32                                                TEA                    31
# 33                                          DIET COKE                    29
# 34                              GATORADE SPORTS DRINK                    29
# 35                                         TOOTHPASTE                    53
# 36                                      FLEXIUM SAM-E                    54
# 37                                   BREATHE EASY TEA                    54
# 38                                        RIPPED FUEL                    54
# 39                                   SIBERIAN GINSENG                    54
# 40                                            EPHEDRA                    54
# 41                                         METABOLIFE                    54
# 42                        PRODUCTS CONTAINING EPHEDRA                    54
# 43                             EPHEDRINE MULTI-ACTION                    54
# 44       STACKER 3 WITH CHITOSAN EPHEDRA FREE FORMULA                    54
# 45                                          ZANTREX 3                    54
# 46                                          XENADRINE                    54
# 47                                         ROMA PIZZA                    37
# 48                                         ROMA PIZZA                    37
# 49                                         ROMA PIZZA                    37
# 50                                             COFFEE                    31
#
#                      PRI_FDA Industry Name      CI_Gender  \
# 1              Bakery Prod/Dough/Mix/Icing         Female
# 2              Bakery Prod/Dough/Mix/Icing         Female
# 3                           Ice Cream Prod         Female
# 4                           Baby Food Prod  Not Available
# 5                           Baby Food Prod  Not Available
# 6                          Snack Food Item           Male
# 7                         Fruit/Fruit Prod  Not Available
# 8   Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 9   Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 10  Vit/Min/Prot/Unconv Diet(Human/Animal)           Male
# 11                        Soft Drink/Water           Male
# 12                        Soft Drink/Water  Not Available
# 13                        Soft Drink/Water  Not Available
# 14                               Cosmetics         Female
# 15             Milk/Butter/Dried Milk Prod         Female
# 16             Milk/Butter/Dried Milk Prod           Male
# 17  Vit/Min/Prot/Unconv Diet(Human/Animal)           Male
# 18  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 19  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 20  Vit/Min/Prot/Unconv Diet(Human/Animal)           Male
# 21  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 22  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 23                              Coffee/Tea           Male
# 24                        Soft Drink/Water           Male
# 25                        Soft Drink/Water           Male
# 26                        Soft Drink/Water           Male
# 27                        Soft Drink/Water           Male
# 28                        Fruit/Fruit Prod           Male
# 29                               Cosmetics           Male
# 30              Food Additives (Human Use)           Male
# 31  Gelatin/Rennet/Pudding Mix/Pie Filling           Male
# 32                              Coffee/Tea           Male
# 33                        Soft Drink/Water           Male
# 34                        Soft Drink/Water           Male
# 35                               Cosmetics           Male
# 36  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 37  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 38  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 39  Vit/Min/Prot/Unconv Diet(Human/Animal)           Male
# 40  Vit/Min/Prot/Unconv Diet(Human/Animal)           Male
# 41  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 42  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 43  Vit/Min/Prot/Unconv Diet(Human/Animal)           Male
# 44  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 45  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 46  Vit/Min/Prot/Unconv Diet(Human/Animal)         Female
# 47     Mult Food Dinner/Grav/Sauce/Special           Male
# 48     Mult Food Dinner/Grav/Sauce/Special  Not Available
# 49     Mult Food Dinner/Grav/Sauce/Special  Not Available
# 50                              Coffee/Tea         Female
#
#                                  AEC_One Row Outcomes  \
# 1   VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 2   VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 3                                       VISITED AN ER
# 4                       NON-SERIOUS INJURIES/ ILLNESS
# 5                      VISITED A HEALTH CARE PROVIDER
# 6                       NON-SERIOUS INJURIES/ ILLNESS
# 7                                               DEATH
# 8                      VISITED A HEALTH CARE PROVIDER
# 9                      VISITED A HEALTH CARE PROVIDER
# 10          REQ. INTERVENTION TO PRVNT PERM. IMPRMNT.
# 11                      NON-SERIOUS INJURIES/ ILLNESS
# 12                      NON-SERIOUS INJURIES/ ILLNESS
# 13                      NON-SERIOUS INJURIES/ ILLNESS
# 14                      NON-SERIOUS INJURIES/ ILLNESS
# 15                      NON-SERIOUS INJURIES/ ILLNESS
# 16                      NON-SERIOUS INJURIES/ ILLNESS
# 17                                              DEATH
# 18                                              DEATH
# 19                  LIFE THREATENING, HOSPITALIZATION
# 20                     VISITED A HEALTH CARE PROVIDER
# 21                     VISITED A HEALTH CARE PROVIDER
# 22                      NON-SERIOUS INJURIES/ ILLNESS
# 23                       LIFE THREATENING, DISABILITY
# 24                       LIFE THREATENING, DISABILITY
# 25                       LIFE THREATENING, DISABILITY
# 26                       LIFE THREATENING, DISABILITY
# 27                       LIFE THREATENING, DISABILITY
# 28                       LIFE THREATENING, DISABILITY
# 29                       LIFE THREATENING, DISABILITY
# 30                       LIFE THREATENING, DISABILITY
# 31                       LIFE THREATENING, DISABILITY
# 32                       LIFE THREATENING, DISABILITY
# 33                      NON-SERIOUS INJURIES/ ILLNESS
# 34                      NON-SERIOUS INJURIES/ ILLNESS
# 35                      NON-SERIOUS INJURIES/ ILLNESS
# 36                     VISITED A HEALTH CARE PROVIDER
# 37                      NON-SERIOUS INJURIES/ ILLNESS
# 38  VISITED A HEALTH CARE PROVIDER, REQ. INTERVENT...
# 39                     VISITED A HEALTH CARE PROVIDER
# 40      DISABILITY, LIFE THREATENING, HOSPITALIZATION
# 41                     VISITED A HEALTH CARE PROVIDER
# 42                     VISITED A HEALTH CARE PROVIDER
# 43                      NON-SERIOUS INJURIES/ ILLNESS
# 44                     VISITED A HEALTH CARE PROVIDER
# 45                                      VISITED AN ER
# 46                      NON-SERIOUS INJURIES/ ILLNESS
# 47                      NON-SERIOUS INJURIES/ ILLNESS
# 48                      NON-SERIOUS INJURIES/ ILLNESS
# 49                      NON-SERIOUS INJURIES/ ILLNESS
# 50                       LIFE THREATENING, DISABILITY
#
#                            SYM_One Row Coded Symptoms year_age
# 1   [SWELLING FACE,  RASH,  WHEEZING,  COUGH,  HOS...        2
# 2   [SWELLING FACE,  WHEEZING,  COUGH,  RASH,  HOS...        2
# 3                    [NAUSEA,  DYSGEUSIA,  DIARRHOEA]       -1
# 4              [GASTROINTESTINAL DISORDER,  VOMITING]     0.25
# 5   [GASTROINTESTINAL DISORDER,  PHYSICAL EXAMINAT...       -1
# 6                                           [CHOKING]       10
# 7                                   [DEATH,  CHOKING]       -1
# 8        [PARANOIA,  PHYSICAL EXAMINATION,  DELUSION]       -1
# 9        [PARANOIA,  PHYSICAL EXAMINATION,  DELUSION]       -1
# 10                         [BLOOD PRESSURE INCREASED]       66
# 11  [RASH,  FLUSHING,  MALAISE,  FAECES PALE,  VOM...       -1
# 12  [LOOSE STOOLS,  ABDOMINAL PAIN UPPER,  VOMITIN...       -1
# 13  [RASH,  LOOSE STOOLS,  ABDOMINAL PAIN UPPER,  ...       -1
# 14                [SWELLING FACE,  PARAESTHESIA ORAL]       -1
# 15                                      [PHARYNGITIS]       -1
# 16                                         [VOMITING]       -1
# 17      [COMPLETED SUICIDE,  STRESS SYMPTOMS,  DEATH]       51
# 18                [DEATH,  MITRAL VALVE INCOMPETENCE]       45
# 19                         [CEREBROVASCULAR ACCIDENT]       54
# 20     [MUCOSAL DISCOLOURATION,  SKIN DISCOLOURATION]       16
# 21  [HEART RATE INCREASED,  DIZZINESS,  BLOOD PRES...       36
# 22                                [PAIN IN EXTREMITY]       48
# 23  [PARAESTHESIA,  PHYSICAL EXAMINATION,  HOSPITA...       33
# 24  [PARAESTHESIA,  PHYSICAL EXAMINATION,  HOSPITA...       33
# 25  [PARAESTHESIA,  PHYSICAL EXAMINATION,  HOSPITA...       33
# 26  [PARAESTHESIA,  PHYSICAL EXAMINATION,  HOSPITA...       33
# 27  [PARAESTHESIA,  PHYSICAL EXAMINATION,  HOSPITA...       33
# 28  [PARAESTHESIA,  PHYSICAL EXAMINATION,  HOSPITA...       33
# 29  [PARAESTHESIA,  PHYSICAL EXAMINATION,  HOSPITA...       33
# 30  [PARAESTHESIA,  PHYSICAL EXAMINATION,  HOSPITA...       33
# 31  [PARAESTHESIA,  PHYSICAL EXAMINATION,  HOSPITA...       33
# 32  [PARAESTHESIA,  PHYSICAL EXAMINATION,  HOSPITA...       33
# 33                                         [ALOPECIA]       14
# 34                                         [ALOPECIA]       14
# 35                                         [ALOPECIA]       14
# 36  [PHYSICAL EXAMINATION,  ARTHRALGIA,  ALOPECIA,...       59
# 37  [PALPITATIONS,  PARANOIA,  PSYCHOTIC DISORDER,...       -1
# 38                            [FACIAL PALSY,  TREMOR]       33
# 39           [DIZZINESS,  BODY TEMPERATURE INCREASED]       29
# 40          [HOSPITALISATION,  MYOCARDIAL INFARCTION]       43
# 41                     [PERIPHERAL VASCULAR DISORDER]       27
# 42                     [PERIPHERAL VASCULAR DISORDER]       27
# 43                               [CHEST PAIN,  COUGH]       42
# 44  [FEELING COLD,  HYPOTENSION,  LOSS OF CONSCIOU...       40
# 45               [FLUSHING,  ERYTHEMA,  PARAESTHESIA]       51
# 46          [PAIN,  TENDERNESS,  HEADACHE,  HEADACHE]       35
# 47                                   [FOOD POISONING]       19
# 48                                   [FOOD POISONING]       -1
# 49                                   [FOOD POISONING]       -1
# 50  [BALANCE DISORDER,  EXTRASYSTOLES,  ORTHOSTATI...       -1
