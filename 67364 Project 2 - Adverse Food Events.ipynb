# %% [markdown]
# # Project 2 - Analyzing Adverse Food Events

# %% [markdown]
# Dylan Schwartz, Jenny Zhu

# %% [markdown]
# ## Project Overview
# Our project will aim to predict the potential symptoms a person may experience after consuming a particular food, given the food type and the person’s age and gender. We are interested in determining if certain food brands or food types can lead to adverse health effects in college students, as well as other age and gender groups. We propose developing a machine learning model to classify records into groups of potential health symptoms based on certain features, such as a person’s age, gender, the food’s brand name, and the food category.

# %% [markdown]
# ## Questions:
#
# 1. What symptoms are most prevalent?
# 2. Given a person’s age, gender, reaction date, and food brand, what is the most likely health outcome, and what are the most likely symptoms to be experienced?
# 3. Can we predict the food a person consumed based on their symptoms?
# 4. What kind of foods should certain demographics avoid eating?

# %% [markdown]
# ## Terminology:

# %% [markdown]
# ### * Cleaning the data *

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import datetime
import collections
from IPython.display import Image

# %matplotlib inline

# %%
# Importing Adverse Food Events Table
app_cols = ['RA_Report #', 'RA_CAERS Created Date', 'AEC_Event Start Date', 'PRI_Product Role', 'PRI_Reported Brand/Product Name', 'PRI_FDA Industry Code', 'PRI_FDA Industry Name', 'CI_Age at Adverse Event', 'CI_Age Unit', 'CI_Gender', 'AEC_One Row Outcomes', 'SYM_One Row Coded Symptoms']
pre_events = pd.read_csv('adversefoodevents.csv', dtype=object , names=app_cols,
                     encoding='latin-1')
# deleting columns that are not needed
pre_events  = pre_events.drop(0)
pre_events = pre_events.drop('RA_Report #', axis=1)
pre_events = pre_events.drop('RA_CAERS Created Date', axis=1)

pre_events.head()
# Out:
#   AEC_Event Start Date PRI_Product Role  \
# 1             8/4/2003          Suspect
# 2             8/4/2003          Suspect
# 3                  NaN          Suspect
# 4           11/24/2003          Suspect
# 5                  NaN          Suspect
#
#                      PRI_Reported Brand/Product Name PRI_FDA Industry Code  \
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                     3
# 2      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                     3
# 3  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                    13
# 4                         ENFAMIL LIPIL BABY FORMULA                    40
# 5                         ENFIMIL LIPIL BABY FORMULA                    40
#
#          PRI_FDA Industry Name CI_Age at Adverse Event    CI_Age Unit  \
# 1  Bakery Prod/Dough/Mix/Icing                       2        Year(s)
# 2  Bakery Prod/Dough/Mix/Icing                       2        Year(s)
# 3               Ice Cream Prod                     NaN  Not Available
# 4               Baby Food Prod                       3       Month(s)
# 5               Baby Food Prod                     NaN  Not Available
#
#        CI_Gender                               AEC_One Row Outcomes  \
# 1         Female  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 2         Female  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 3         Female                                      VISITED AN ER
# 4  Not Available                      NON-SERIOUS INJURIES/ ILLNESS
# 5  Not Available                     VISITED A HEALTH CARE PROVIDER
#
#                           SYM_One Row Coded Symptoms
# 1  SWELLING FACE, RASH, WHEEZING, COUGH, HOSPITAL...
# 2  SWELLING FACE, WHEEZING, COUGH, RASH, HOSPITAL...
# 3                       NAUSEA, DYSGEUSIA, DIARRHOEA
# 4                GASTROINTESTINAL DISORDER, VOMITING
# 5    GASTROINTESTINAL DISORDER, PHYSICAL EXAMINATION

# %%
# # Creating events table (cleaned version of the pre_events table)

# ## HELPER FUNCTIONS #####

# # Helper function that assigns empty start date values to the current date
def clean_start_date(v):
    if pd.isnull(v):
        return datetime.datetime.now().strftime("%Y-%m-%d")
    else:
        date = v.split("/")
        c_date = datetime.date(int(date[2]), int(date[0]), int(date[1])).strftime("%Y-%m-%d")
        return c_date

def get_age(row):
    age = row['CI_Age at Adverse Event']
    if(pd.isnull(age) or isinstance(int(age), int) == False):
        return '-1' 
    elif(row['CI_Age Unit'] == 'Month(s)'):
        return str(int(age)/12)
    else:
        return age

# # Helper function that converts comma-separated symptoms into a list
def list_symptoms(x): 
    if(isinstance(x, str)):
        symptoms_list = x.split(",")
        return symptoms_list
    else:
        return []


# ##########################

# #creating cleaned food events dataframes 
events = pre_events.copy(deep=True)

# # Cleaning adverse reaction start date
events['AEC_Event Start Date'] = pre_events['AEC_Event Start Date'].apply( lambda v: clean_start_date(v))

# # Making a new column for the patient's age in years
events['year_age'] = pre_events.apply( lambda row: get_age(row), axis=1)
events = events.drop('CI_Age at Adverse Event', axis=1)
events = events.drop('CI_Age Unit', axis=1)

# # # Converting comma-separated symptoms into a list of symptoms 
events['SYM_One Row Coded Symptoms'] = pre_events['SYM_One Row Coded Symptoms'].apply( lambda x: list_symptoms(x))

events.head(50)

print('Total rows: ', len(pre_events), '\n')
print('Age available: ', len(pre_events.loc[pre_events['CI_Age at Adverse Event'].notnull()]))
print('Age null: ', len(pre_events.loc[pre_events['CI_Age at Adverse Event'].notnull() == False]))

print('Gender available: ', len(pre_events.loc[pre_events['CI_Gender'] != 'Not Available']))
print('Gender null: ', len(pre_events.loc[pre_events['CI_Gender'] == 'Not Available']))

print('Date available: ', len(pre_events.loc[pre_events['AEC_Event Start Date'].notnull()]))
print('Date null: ', len(pre_events.loc[pre_events['AEC_Event Start Date'].notnull() == False]))

print('Product available: ', len(pre_events.loc[pre_events['PRI_Reported Brand/Product Name'] != 'Not Available']))
print('Product null: ', len(pre_events.loc[pre_events['PRI_Reported Brand/Product Name'] == 'Not Available']))

print('Outcome available: ', len(pre_events.loc[pre_events['AEC_One Row Outcomes'].notnull()]))
print('Outcome null: ', len(pre_events.loc[pre_events['AEC_One Row Outcomes'].notnull() == False]))

pre_events.loc[pre_events['CI_Age at Adverse Event'].notnull() == False]
# Out:
# Total rows:  90786
#
# Age available:  52926
# Age null:  37860
# Gender available:  85870
# Gender null:  4916
# Date available:  53653
# Date null:  37133
# Product available:  90786
# Product null:  0
# Outcome available:  90786
# Outcome null:  0
#       AEC_Event Start Date PRI_Product Role  \
# 3                      NaN          Suspect
# 5                      NaN          Suspect
# 7                      NaN          Suspect
# 8                12/1/2003          Suspect
# 9                12/1/2003          Suspect
# 11              10/27/2003          Suspect
# 12              10/27/2003          Suspect
# 13              10/27/2003          Suspect
# 14               11/5/2003          Suspect
# 15                     NaN          Suspect
# 16              12/30/2003          Suspect
# 37                1/1/1996          Suspect
# 48              12/31/2003          Suspect
# 49              12/31/2003          Suspect
# 50               11/1/2003          Suspect
# 51               11/1/2003          Suspect
# 52               11/1/2003          Suspect
# 53               11/1/2003          Suspect
# 54               11/1/2003          Suspect
# 55               11/1/2003          Suspect
# 58                3/7/2003          Suspect
# 59                4/7/2003          Suspect
# 60              11/22/2003          Suspect
# 61                     NaN          Suspect
# 63                1/3/2004          Suspect
# 64                     NaN          Suspect
# 65                     NaN          Suspect
# 66              11/23/2003          Suspect
# 68               7/17/2003          Suspect
# 70               6/16/2003          Suspect
# ...                    ...              ...
# 90706                  NaN          Suspect
# 90708             4/8/2017          Suspect
# 90709            6/11/2017          Suspect
# 90717                  NaN          Suspect
# 90718            4/29/2017          Suspect
# 90719            6/10/2017          Suspect
# 90720             1/2/2017          Suspect
# 90737                  NaN          Suspect
# 90738                  NaN          Suspect
# 90739                  NaN          Suspect
# 90740             3/3/2017          Suspect
# 90741            11/7/2016          Suspect
# 90742            11/7/2016          Suspect
# 90743            11/7/2016          Suspect
# 90744            1/21/2017          Suspect
# 90745            2/18/2017          Suspect
# 90750            3/11/2017          Suspect
# 90753            2/28/2017          Suspect
# 90756            5/18/2017          Suspect
# 90757                  NaN          Suspect
# 90762                  NaN          Suspect
# 90763            6/27/2017          Suspect
# 90764            3/11/2017          Suspect
# 90765                  NaN          Suspect
# 90770             1/8/2017      Concomitant
# 90771             1/8/2017          Suspect
# 90772                  NaN          Suspect
# 90773            6/20/2017          Suspect
# 90785                  NaN          Suspect
# 90786                  NaN          Suspect
#
#                          PRI_Reported Brand/Product Name  \
# 3      KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...
# 5                             ENFIMIL LIPIL BABY FORMULA
# 7                                                  GRAPE
# 8                                    HERBALIFE RELAX NOW
# 9                                HERBALIFE TOTAL CONTROL
# 11            CAL-C PEACH TROPIC ENRICHED BEVERAGE BLEND
# 12            CAL-C PEACH TROPIC ENRICHED BEVERAGE BLEND
# 13            CAL-C PEACH TROPIC ENRICHED BEVERAGE BLEND
# 14                    I CONTACT LIP-INK (SEMI-PERMANENT)
# 15                               H.P. HOOD HALF AND HALF
# 16      LACTAID REDUCED FAT (2%) MILK; 100% LACTOSE FREE
# 37                                      BREATHE EASY TEA
# 48                                            ROMA PIZZA
# 49                                            ROMA PIZZA
# 50                                                COFFEE
# 51                               DIET CAFFEINE FREE COKE
  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 48                       37     Mult Food Dinner/Grav/Sauce/Special
# 49                       37     Mult Food Dinner/Grav/Sauce/Special
# 50                       31                              Coffee/Tea
# 51                       29                        Soft Drink/Water
# 52                       29                        Soft Drink/Water
# 53                       22                        Fruit/Fruit Prod
# 54                       45              Food Additives (Human Use)
# 55                       35  Gelatin/Rennet/Pudding Mix/Pie Filling
# 58                        4                    Macaroni/Noodle Prod
# 59                       21                        Fruit/Fruit Prod
# 60                        3             Bakery Prod/Dough/Mix/Icing
# 61                       24           Vegetables/Vegetable Products
# 63                       31                              Coffee/Tea
# 64                        5              Cereal Prep/Breakfast Food
# 65                       41     Dietary Conv Food/Meal Replacements
# 66                       34                         Choc/Cocoa Prod
# 68                        7                         Snack Food Item
# 70                       13                          Ice Cream Prod
# ...                     ...                                     ...
# 90706                     3             Bakery Prod/Dough/Mix/Icing
# 90708                    16                    Fishery/Seafood Prod
# 90709                    15                            Egg/Egg Prod
# 90717                    20                        Fruit/Fruit Prod
# 90718                    16                    Fishery/Seafood Prod
# 90719                     5              Cereal Prep/Breakfast Food
# 90720                    45              Food Additives (Human Use)
# 90737                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 90738                     9             Milk/Butter/Dried Milk Prod
# 90739                     9             Milk/Butter/Dried Milk Prod
# 90740                    28               Spices, Flavors And Salts
# 90741                    23                        Nuts/Edible Seed
# 90742                    23                        Nuts/Edible Seed
# 90743                    23                        Nuts/Edible Seed
# 90744                    22                        Fruit/Fruit Prod
# 90745                    16                    Fishery/Seafood Prod
# 90750                    17         Meat, Meat Products and Poultry
# 90753                    21                        Fruit/Fruit Prod
# 90756                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 90757                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 90762                    24           Vegetables/Vegetable Products
# 90763                    31                              Coffee/Tea
# 90764                     3             Bakery Prod/Dough/Mix/Icing
# 90765                    53                               Cosmetics
# 90770                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 90771                    53                               Cosmetics
# 90772                    53                               Cosmetics
# 90773                    53                               Cosmetics
# 90785                    53                               Cosmetics
# 90786                    53                               Cosmetics
#
#       CI_Age at Adverse Event    CI_Age Unit      CI_Gender  \
# 3                         NaN  Not Available         Female
# 5                         NaN  Not Available  Not Available
# 7                         NaN  Not Available  Not Available
# 8                         NaN  Not Available         Female
# 9                         NaN  Not Available         Female
# 11                        NaN  Not Available           Male
# 12                        NaN  Not Available  Not Available
# 13                        NaN  Not Available  Not Available
# 14                        NaN  Not Available         Female
# 15                        NaN  Not Available         Female
# 16                        NaN  Not Available           Male
# 37                        NaN  Not Available         Female
# 48                        NaN  Not Available  Not Available
# 49                        NaN  Not Available  Not Available
# 50                        NaN  Not Available         Female
# 51                        NaN  Not Available         Female
# 52                        NaN  Not Available         Female
# 53                        NaN  Not Available         Female
# 54                        NaN  Not Available         Female
# 55                        NaN  Not Available         Female
# 66                         NON-SERIOUS INJURIES/ ILLNESS
# 68                         NON-SERIOUS INJURIES/ ILLNESS
# 70                         NON-SERIOUS INJURIES/ ILLNESS
# ...                                                  ...
# 90706                      NON-SERIOUS INJURIES/ ILLNESS
# 90708           OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)
# 90709           OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)
# 90717       NON-SERIOUS INJURIES/ ILLNESS, VISITED AN ER
# 90718  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 90719                      NON-SERIOUS INJURIES/ ILLNESS
# 90720                      NON-SERIOUS INJURIES/ ILLNESS
# 90737                      NON-SERIOUS INJURIES/ ILLNESS
# 90738  VISITED A HEALTH CARE PROVIDER, NON-SERIOUS IN...
# 90739  VISITED A HEALTH CARE PROVIDER, NON-SERIOUS IN...
# 90740                      NON-SERIOUS INJURIES/ ILLNESS
# 90741       NON-SERIOUS INJURIES/ ILLNESS, VISITED AN ER
# 90742       NON-SERIOUS INJURIES/ ILLNESS, VISITED AN ER
# 90743       NON-SERIOUS INJURIES/ ILLNESS, VISITED AN ER
# 90744                      NON-SERIOUS INJURIES/ ILLNESS
# 90745                      NON-SERIOUS INJURIES/ ILLNESS
# 90750           OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)
# 90753                      NON-SERIOUS INJURIES/ ILLNESS
# 90756                                    HOSPITALIZATION
# 90757           OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)
# 90762                      NON-SERIOUS INJURIES/ ILLNESS
# 90763                      NON-SERIOUS INJURIES/ ILLNESS
# 90764          REQ. INTERVENTION TO PRVNT PERM. IMPRMNT.
# 90765                                      VISITED AN ER
# 90770         VISITED A HEALTH CARE PROVIDER, DISABILITY
# 90771         VISITED A HEALTH CARE PROVIDER, DISABILITY
# 90772                     VISITED A HEALTH CARE PROVIDER
# 90773           OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)
# 90785                      NON-SERIOUS INJURIES/ ILLNESS
# 90786                      NON-SERIOUS INJURIES/ ILLNESS
#
#                               SYM_One Row Coded Symptoms
# 3                           NAUSEA, DYSGEUSIA, DIARRHOEA
# 5        GASTROINTESTINAL DISORDER, PHYSICAL EXAMINATION
# 7                                         DEATH, CHOKING
# 8               PARANOIA, PHYSICAL EXAMINATION, DELUSION
# 9               PARANOIA, PHYSICAL EXAMINATION, DELUSION
# 11     RASH, FLUSHING, MALAISE, FAECES PALE, VOMITING...
# 12     LOOSE STOOLS, ABDOMINAL PAIN UPPER, VOMITING, ...
# 13     RASH, LOOSE STOOLS, ABDOMINAL PAIN UPPER, MALA...
# 14                      SWELLING FACE, PARAESTHESIA ORAL
# 15                                           PHARYNGITIS
# 16                                              VOMITING
# 37     PALPITATIONS, PARANOIA, PSYCHOTIC DISORDER, HY...
# 48                                        FOOD POISONING
# 49                                        FOOD POISONING
# 50     BALANCE DISORDER, EXTRASYSTOLES, ORTHOSTATIC H...
# 51     BALANCE DISORDER, ORTHOSTATIC HYPOTENSION, BLO...
# 52     BALANCE DISORDER, ORTHOSTATIC HYPOTENSION, BLO...
# 53     BALANCE DISORDER, ORTHOSTATIC HYPOTENSION, BLO...
# 54     BALANCE DISORDER, ORTHOSTATIC HYPOTENSION, BLO...
# 55     BALANCE DISORDER, ORTHOSTATIC HYPOTENSION, BLO...
# 58                  MALAISE, NAUSEA, ASTHENIA, DIZZINESS
# 59                                  ABDOMINAL PAIN UPPER
# 60                                       ORAL DISCOMFORT
# 61                                         HAEMATOCHEZIA
# 63     MALAISE, VOMITING, GASTROINTESTINAL DISORDER, ...
# 64           HYPOAESTHESIA ORAL, PARAESTHESIA, DIARRHOEA
# 65       HEADACHE, ABDOMINAL PAIN, DIARRHOEA, FLATULENCE
# 66                                                NAUSEA
# 68                      HYPERHIDROSIS, VOMITING, MALAISE
# 70                                               CHOKING
# ...                                                  ...
# 90706                                          DIARRHOEA
# 90708                                             NAUSEA
# 90709                                          DIARRHOEA
# 90717                                               RASH
# 90718  ABDOMINAL PAIN, VOMITING, NAUSEA, ABDOMINAL PA...
# 90719                                  NAUSEA, DYSGEUSIA
# 90720    BLOOD GLUCOSE ABNORMAL, BLOOD GLUCOSE INCREASED
# 90737                                DIARRHOEA, VOMITING
# 90738  BURNING SENSATION, GASTROOESOPHAGEAL REFLUX DI...
# 90739  BURNING SENSATION, GASTROOESOPHAGEAL REFLUX DI...
# 90740       METAL POISONING, BLOOD HEAVY METAL INCREASED
# 90741      ABDOMINAL PAIN, MALAISE, ABDOMINAL PAIN UPPER
# 90742      ABDOMINAL PAIN, MALAISE, ABDOMINAL PAIN UPPER
# 90743      ABDOMINAL PAIN, ABDOMINAL PAIN UPPER, MALAISE
# 90744  DIARRHOEA, NAUSEA, VOMITING, GASTROINTESTINAL ...
# 90745  DIARRHOEA, NAUSEA, HEADACHE, FEELING OF BODY T...
# 90750  MALAISE, VOMITING, ABDOMINAL PAIN UPPER, ABDOM...
# 90753                 ABDOMINAL PAIN, DIARRHOEA, MALAISE
# 90756                  SINUS RHYTHM, ATRIAL FIBRILLATION
# 90757  MALAISE, LOSS OF CONSCIOUSNESS, HEART RATE INC...
# 90762                                     LOCAL SWELLING
# 90763                  MUSCLE SPASMS, VOMITING, HEADACHE
# 90764  DIARRHOEA, PYREXIA, VOMITING, DECREASED APPETI...
# 90765                                       EYE SWELLING
# 90770             URTICARIA, SWELLING FACE, EYE SWELLING
# 90771             URTICARIA, SWELLING FACE, EYE SWELLING
# 90772                   CHEMICAL INJURY, WOUND, SWELLING
# 90773                                     EYE IRRITATION
# 90785                          VOMITING, URTICARIA, RASH
# 90786                          VOMITING, URTICARIA, RASH
#
# [37860 rows x 10 columns]
